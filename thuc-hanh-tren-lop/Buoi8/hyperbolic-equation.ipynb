# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f_x_bai1(x, l):
    if x <= 0.8*l:
        return 1.25*x/l
    else:
        return 5 - 5*x/l

def g_x_bai1(x, l):
    g_x  = 0
    return g_x

def khoitao_u(dt, dx, tmax, L,f_x, g_x):
    n = int(tmax / dt) + 1   # n la thoi gian
    m = int(L / dx) + 1   # m la khong gian

    u = np.zeros((n, m))
    x = np.linspace(0, L, m)
    t = np.linspace(0, tmax, n)

    # Dieu kien dau theo thoi gian: u(0,x) = f(x), 
    for j in range(m):
        u[0, j] = f_x(x[j], L)
        u[1, j] = u[0, j] + dt * g_x(x[j], L)


    # Dieu kien theo khong gian tai moi thoi diem: u(0,t) = u(L,t) = 0
    u[:, 0] = 0.0
    u[:, -1] = 0.0

    return u, x, t

def tinh_beta(c,k,h):
    beta  = c * k / h
    if beta > 1:
        print("Canh bao: beta =", beta, " > 1. Phuong phap co the khong on dinh.")
        ondinh = False
    else:
        ondinh = True
        return beta, ondinh

# %%
def ghifile(u, x, t, filename):
    with open(filename, "w", encoding="utf-8") as file:
        file.write("# Bai toan truyen song 1D\n")
        file.write("# Phuong phap sai phan huu han hien\n")
        file.write("#\n")
        file.write(f"# N_x    = {x.shape[0]}\n")
        file.write(f"# N_time = {t.shape[0]}\n")
        file.write(f"# l      = {x[-1]}\n")
        file.write(f"# t_max  = {t[-1]}\n")
        file.write("#\n")
        file.write(f"# {'t_step':>10s} {'x_step':>10s} {'t':>15s} {'x':>15s} {'u':>15s}\n")

        for t_step in range(t.shape[0]):
            for x_step in range(x.shape[0]):
                file.write(f"  {t_step:10d} {x_step:10d} {t[t_step]:15.8e} {x[x_step]:15.8e} {u[t_step, x_step]:15.8e}\n")
            file.write("\n")

# %%
def ham_forward(c,k,h, tmax, L, f_x, g_x, filename):
    u, x ,t  = khoitao_u(k, h, tmax, L, f_x, g_x)
    n,m = u.shape
    beta, ondinh = tinh_beta(c, k, h)
    if ondinh == True:
        for i in range(1,n-1): # n la thoi gian
            for j in range(1,m-1): #  m la khong gian
                u[i+1,j] = 2*(1-beta**2)*u[i,j] + beta**2*(u[i,j+1]+u[i,j-1]) - u[i-1,j]
        ghifile(u, x, t, filename)
    else:
        print("Phuong phap khong on dinh, khong the tinh toan.")
    return

# %%
L       = 1.0      # Chieu dai day
c       = 1.0      # Van toc song
t_max   = 5.0      # Thoi gian mo phong
delta_x = 0.005    # Buoc khong gian  -> 201 diem
delta_t = 0.0025   # Buoc thoi gian   -> beta = c*dt/dx = 0.5 (on dinh)

# %%
ham_forward(c=1, k=delta_t, h=delta_x, tmax=t_max, L=L, f_x=f_x_bai1, g_x=g_x_bai1, filename="ketqua.txt")

# %% [markdown]
# ## Doi ham f ban dau sang sin

# %%
def f_x_bai2(x, l):
    return np.sin(x * np.pi / l)

def g_x_bai2(x, l):
    return 0

f_x_bai2 = f_x_bai2
g_x_bai2 = g_x_bai2

ham_forward(c=1, k=delta_t, h=delta_x, tmax=t_max, L=L, f_x=f_x_bai2, g_x=g_x_bai2, filename="ketqua_hamsin.txt")
