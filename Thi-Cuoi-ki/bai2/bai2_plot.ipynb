# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("sci.mplstyle")

# %%
t_baytu, x_baytu, y_baytu, z_baytu, vx_baytu, vy_baytu, vz_baytu= np.loadtxt("KQ_bai2-baytu-RK4.txt", comments="#", unpack=True)

# %%
fig = plt.figure(figsize=(9, 9))
ax = fig.add_subplot(111, projection='3d')

ax.plot(x_baytu, y_baytu, z_baytu, color='C0', linewidth=2)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title("Quy dao trong bay tu (Python)")
ax.view_init(elev=20, azim=20)
plt.savefig("KQ_bai2-baytu-RK4-3D.png", dpi=300)
plt.show()
