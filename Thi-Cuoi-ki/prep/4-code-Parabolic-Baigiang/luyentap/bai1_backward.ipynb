# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("sci.mplstyle")

# %%
def tinh_he_so_backward(kappa, C, rho, N_x, N_time, L, t_max):
    h = L / (N_x - 1) # buoc luoi khong gian
    k = t_max / (N_time - 1) # buoc luoi thoi gian

    alpha = np.sqrt(kappa / (C * rho))

    eta = alpha**2 * k / h**2

    beta1 = eta / (1.0 + 2.0 * eta)
    beta2 = 1.0 / (1.0 + 2.0 * eta)

    return eta, beta1, beta2, h, k

# %%
def ham_ghi_file(file, dk_bai_toan): # dung de ghi thong tin quan trong ra file

    file.write(f"# {dk_bai_toan['mo_ta']}\n")
    file.write("# Backward Euler cho phuong trinh truyen nhiet 1D\n")

    file.write("#\n")

    file.write(f"# N_x    = {dk_bai_toan['N_x']}\n")
    file.write(f"# N_time = {dk_bai_toan['N_time']}\n")
    file.write(f"# L      = {dk_bai_toan['L']}\n")
    file.write(f"# t_max  = {dk_bai_toan['t_max']}\n")
    file.write(f"# h      = {dk_bai_toan['h']:.8e}\n")
    file.write(f"# k      = {dk_bai_toan['k']:.8e}\n")
    file.write(f"# eta    = {dk_bai_toan['eta']:.8e}\n")

    file.write("#\n")
    file.write(f"# {'j (t)':>8s} {'i (x)':>8s} {'t':>15s} {'x':>15s} {'u':>15s}\n")

def ham_luu_dulieu(filename, u, dk_bai_toan, skip_buoc_thoigian):
    N_x = dk_bai_toan["N_x"]
    N_time = dk_bai_toan["N_time"]
    h = dk_bai_toan["h"]
    k = dk_bai_toan["k"]

    with open(filename, "w", encoding="utf-8") as file:
        ham_ghi_file(file, dk_bai_toan)

        for j in range(N_time):
            if j % skip_buoc_thoigian != 0 and j != N_time - 1: # khi j khong chia het cho skip_buoc_thoigian thi bo qua data do va lay luon  data cuoi cung
                continue
            t = j * k

            for i in range(N_x):
                x = i * h
                file.write(f"  {j:8d} {i:8d} {t:15.6e} {x:15.6e} {u[i, j]:15.6e}\n")

            file.write("\n")

def ham_luu_hoitu(filename, bang_hoitu): # dung de luu so vong lap hoi tu

    with open(filename, "w", encoding="utf-8") as file:
        file.write("# Ket qua hoi tu cua Backward Euler\n")
        file.write(f"# {'j (t_step)':>15s} {'q (so vong lap)':>15s} {'max_err':>15s}\n")

        for j, q, max_err in bang_hoitu:
            file.write(f"  {j:15d} {q:15d} {max_err:15.6e}\n")

# %%
def ham_tinh_backward_euler(u,kappa,C,rho,L,t_max,N_max,tol,filename,mo_ta, skip_buoc_thoigian = 20):

    N_x = u.shape[0]
    N_time = u.shape[1]

    eta, beta1, beta2, h, k = tinh_he_so_backward(
        kappa, C, rho, N_x, N_time, L, t_max
    )

    bang_hoitu = []

    # Vong lap cho thoi gian
    for j in range(1, N_time):

        # Lay nghiem cua buoc truoc lam gia tri doan ban dau
        for i in range(1, N_x - 1):
            u[i, j] = u[i, j - 1]

        # Lap de giai so, voi moi buoc thoi gian thi phai lap de hoi tu tai buoc do
        for q in range(1, N_max + 1):

            u_old = u[:, j].copy()

            for i in range(1, N_x - 1):
                u[i, j] = (
                    beta1 * (u[i + 1, j] + u[i - 1, j])
                    + beta2 * u[i, j - 1]
                )

            max_err = np.max(np.abs(u[:, j] - u_old)) # sai so lon nhat tai moi buoc x (lay lam dai dien cho buoc thoi gian do)

            if max_err < tol:
                bang_hoitu.append((j, q, max_err)) # ghi lai so vong lap cho moi lan hoi tu

                if np.mod(j, 50) == 0: # in ra so vong lap cho moi lan hoi tu
                    print(
                        f"j = {j}, hoi tu sau q = {q} vong lap, "
                        f"max_err = {max_err:.3e}"
                    )

                break

    dk_bai_toan = {
        "mo_ta": mo_ta,
        "N_x": N_x,
        "N_time": N_time,
        "L": L,
        "t_max": t_max,
        "h": h,
        "k": k,
        "eta": eta,
    }

    ham_luu_dulieu(filename + "_backward_result.txt", u, dk_bai_toan, skip_buoc_thoigian)

    ham_luu_hoitu(filename + "_backward_hoitu.txt", bang_hoitu)

    print("Da tinh xong Backward Euler")
    print(f"eta = {eta:.6e}")
    print(f"beta1 = {beta1:.6e}")
    print(f"beta2 = {beta2:.6e}")
    print(f"Da luu file: {filename + "_backward_result.txt"}")

    return u, dk_bai_toan

# %%
# =========================================================
# Bai 1: mot thanh
# =========================================================

def tao_dieu_kien_bien_bai1(N_time, N_x, L, T_ban_dau, T_trai, T_phai):
    """
    Bai 1:
        Thanh dai L
        Ban dau: T(x, 0) = T_ban_dau
        Hai dau: T(0, t) = T_trai, T(L, t) = T_phai

    N_time    : so diem thoi gian
    N_x       : so diem khong gian
    L         : chieu dai thanh
    T_ban_dau : nhiet do ban dau cua thanh
    T_trai    : nhiet do dau trai
    T_phai    : nhiet do dau phai
    """

    x = np.linspace(0.0, L, N_x)
    u = np.zeros((N_x, N_time), dtype=float)

    # Dieu kien dau: T(x, 0) = T_ban_dau
    for i in range(N_x):
        u[i, 0] = T_ban_dau

    # Dieu kien bien trai: T(0, t) = T_trai
    for j in range(N_time):
        u[0, j] = T_trai

    # Dieu kien bien phai: T(L, t) = T_phai
    for j in range(N_time):
        u[N_x - 1, j] = T_phai

    # Tai t = 0, uu tien dieu kien bien tai hai dau
    u[0, 0] = T_trai
    u[N_x - 1, 0] = T_phai

    return u, x

N_time = 3000
N_x = 200

L = 1.0
t_max = 2500.0

T_ban_dau = 0.0
T_trai = 100.0
T_phai = 100.0

kappa = 210.0
C = 900.0
rho = 2700.0

tol  = 1e-6
N_max = 10000

u, x = tao_dieu_kien_bien_bai1(
    N_time=N_time,
    N_x=N_x,
    L=L,
    T_ban_dau=T_ban_dau,
    T_trai=T_trai,
    T_phai=T_phai,
)

# u,kappa,C,rho,L,t_max,N_max,tol,filename,mo_ta, skip_buoc_thoigian = 20

u, info = ham_tinh_backward_euler(
    u=u,
    kappa=kappa,
    C=C,
    rho=rho,
    L=L,
    t_max=t_max,
    N_max=N_max,
    tol = tol,
    filename="truyen_nhiet_1thanh_claude_bai1",
    mo_ta="Bai toan truyen nhiet 1D: mot thanh",
    skip_buoc_thoigian = 20,
)
# Out:
# j = 50, hoi tu sau q = 40 vong lap, max_err = 8.966e-07
# j = 100, hoi tu sau q = 38 vong lap, max_err = 8.740e-07
# j = 150, hoi tu sau q = 37 vong lap, max_err = 8.045e-07
# j = 200, hoi tu sau q = 36 vong lap, max_err = 8.243e-07
# j = 250, hoi tu sau q = 35 vong lap, max_err = 8.976e-07
# j = 300, hoi tu sau q = 35 vong lap, max_err = 7.543e-07
# j = 350, hoi tu sau q = 34 vong lap, max_err = 8.867e-07
# j = 400, hoi tu sau q = 34 vong lap, max_err = 7.958e-07
# j = 450, hoi tu sau q = 33 vong lap, max_err = 9.943e-07
# j = 500, hoi tu sau q = 33 vong lap, max_err = 9.459e-07
# j = 550, hoi tu sau q = 33 vong lap, max_err = 9.239e-07
# j = 600, hoi tu sau q = 33 vong lap, max_err = 9.199e-07
# j = 650, hoi tu sau q = 33 vong lap, max_err = 9.111e-07
# j = 700, hoi tu sau q = 33 vong lap, max_err = 8.962e-07
# j = 750, hoi tu sau q = 33 vong lap, max_err = 8.773e-07
# j = 800, hoi tu sau q = 33 vong lap, max_err = 8.556e-07
# j = 850, hoi tu sau q = 33 vong lap, max_err = 8.323e-07
# j = 900, hoi tu sau q = 33 vong lap, max_err = 8.080e-07
# j = 950, hoi tu sau q = 33 vong lap, max_err = 7.832e-07
# j = 1000, hoi tu sau q = 33 vong lap, max_err = 7.584e-07
# j = 1050, hoi tu sau q = 32 vong lap, max_err = 9.911e-07
# j = 1100, hoi tu sau q = 32 vong lap, max_err = 9.583e-07
# j = 1150, hoi tu sau q = 32 vong lap, max_err = 9.261e-07
# j = 1200, hoi tu sau q = 32 vong lap, max_err = 8.947e-07
# j = 1250, hoi tu sau q = 32 vong lap, max_err = 8.642e-07
# j = 1300, hoi tu sau q = 32 vong lap, max_err = 8.345e-07
# j = 1350, hoi tu sau q = 32 vong lap, max_err = 8.058e-07
# j = 1400, hoi tu sau q = 32 vong lap, max_err = 7.779e-07
# j = 1450, hoi tu sau q = 32 vong lap, max_err = 7.509e-07
# j = 1500, hoi tu sau q = 31 vong lap, max_err = 9.791e-07
# j = 1550, hoi tu sau q = 31 vong lap, max_err = 9.450e-07
# j = 1600, hoi tu sau q = 31 vong lap, max_err = 9.121e-07
# j = 1650, hoi tu sau q = 31 vong lap, max_err = 8.804e-07
# j = 1700, hoi tu sau q = 31 vong lap, max_err = 8.497e-07
# j = 1750, hoi tu sau q = 31 vong lap, max_err = 8.201e-07
# j = 1800, hoi tu sau q = 31 vong lap, max_err = 7.915e-07
# j = 1850, hoi tu sau q = 31 vong lap, max_err = 7.638e-07
# j = 1900, hoi tu sau q = 30 vong lap, max_err = 9.958e-07
# j = 1950, hoi tu sau q = 30 vong lap, max_err = 9.610e-07
# j = 2000, hoi tu sau q = 30 vong lap, max_err = 9.275e-07
# j = 2050, hoi tu sau q = 30 vong lap, max_err = 8.951e-07
# j = 2100, hoi tu sau q = 30 vong lap, max_err = 8.639e-07
# j = 2150, hoi tu sau q = 30 vong lap, max_err = 8.337e-07
# j = 2200, hoi tu sau q = 30 vong lap, max_err = 8.046e-07
# j = 2250, hoi tu sau q = 30 vong lap, max_err = 7.765e-07
# j = 2300, hoi tu sau q = 30 vong lap, max_err = 7.494e-07
# j = 2350, hoi tu sau q = 29 vong lap, max_err = 9.770e-07
# j = 2400, hoi tu sau q = 29 vong lap, max_err = 9.429e-07
# j = 2450, hoi tu sau q = 29 vong lap, max_err = 9.099e-07
# j = 2500, hoi tu sau q = 29 vong lap, max_err = 8.782e-07
# j = 2550, hoi tu sau q = 29 vong lap, max_err = 8.475e-07
# j = 2600, hoi tu sau q = 29 vong lap, max_err = 8.179e-07
# j = 2650, hoi tu sau q = 29 vong lap, max_err = 7.894e-07
# j = 2700, hoi tu sau q = 29 vong lap, max_err = 7.618e-07
# j = 2750, hoi tu sau q = 28 vong lap, max_err = 9.931e-07
# j = 2800, hoi tu sau q = 28 vong lap, max_err = 9.584e-07
# j = 2850, hoi tu sau q = 28 vong lap, max_err = 9.250e-07
# j = 2900, hoi tu sau q = 28 vong lap, max_err = 8.927e-07
# j = 2950, hoi tu sau q = 28 vong lap, max_err = 8.615e-07
# Da tinh xong Backward Euler
# eta = 2.852875e+00
# beta1 = 4.254371e-01
# beta2 = 1.491258e-01
# Da luu file: truyen_nhiet_1thanh_claude_bai1_backward_result.txt

# %%
def ham_doc_file(filename):
    data = np.loadtxt(filename, comments="#")

    t_raw = data[:, 2]
    x_raw = data[:, 3]
    u_raw = data[:, 4]

    x = np.unique(x_raw)
    t = np.unique(t_raw)

    N_x = len(x)
    N_time = len(t)

    print("File:", filename)
    print("N_x =", N_x)
    print("N_time =", N_time)
    print("So diem =", len(u_raw))
    print("N_x * N_time =", N_x * N_time)

    if N_x * N_time != len(u_raw):
        raise ValueError("File khong phai luoi day du theo x va t")

    # file ghi theo:
    # for j in range(N_time):
    #     for i in range(N_x):
    temp = u_raw.reshape(N_time, N_x)

    return x, t, temp

# %%
x_backward_1thanh_claude_bai1 , t_backward_1thanh_claude_bai1, temp_backward_1thanh_claude_bai1 = ham_doc_file("truyen_nhiet_1thanh_claude_bai1_backward_result.txt")
# Out:
# File: truyen_nhiet_1thanh_claude_bai1_backward_result.txt
# N_x = 200
# N_time = 151
# So diem = 30200
# N_x * N_time = 30200

# %%
plt.figure(figsize=(9, 6))

plt.imshow(
    temp_backward_1thanh_claude_bai1,
    extent=[x_backward_1thanh_claude_bai1.min(), x_backward_1thanh_claude_bai1.max(), t_backward_1thanh_claude_bai1.min(), t_backward_1thanh_claude_bai1.max()],
    origin="lower",
    aspect="auto",
    cmap = "coolwarm"
)

plt.xlabel("Toa do (x)")
plt.ylabel("Thoi gian (t)")
plt.colorbar(label=" Nhiet do (x,t)")
plt.savefig("truyen_nhiet_1thanh_claude_bai1_backward.png", dpi =300)
plt.show()

# %%
fig = plt.figure(figsize=(9, 9))
ax = fig.add_subplot(111, projection='3d')

X_1thanh, T_1thanh = np.meshgrid(x_backward_1thanh_claude_bai1, t_backward_1thanh_claude_bai1)

ax.plot_surface(X_1thanh, T_1thanh, temp_backward_1thanh_claude_bai1, color='white', edgecolor='gray', linewidth=0.3)
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('Temp')
ax.view_init(elev=20, azim=40)
plt.savefig("truyen_nhiet_1thanh_claude_bai1_backward-3D.png", dpi=300)
plt.show()
